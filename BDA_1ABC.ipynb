# %% [markdown]
# <a href="https://colab.research.google.com/github/polarpubhanu/BIG-DATA-ANALYTICS/blob/main/BDA_1ABC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files
uploaded = files.upload()
df = pd.read_csv('large_sales_data (1).csv')
print("First 5 records:")
print(df.head())

print("\nDataset Information:")
print(df.info())

print("\nDescriptive Statistics:")
print(df.describe())

print("\nSales Statistics:")
print("Mean:", df['Sales'].mean())
print("Median:", df['Sales'].median())
print("Mode:", df['Sales'].mode()[0])
print("Minimum:", df['Sales'].min())
print("Maximum:", df['Sales'].max())
print("Standard Deviation:", df['Sales'].std())
print("Variance:", df['Sales'].var())

print("\nProfit Statistics:")
print("Mean Profit:", df['Profit'].mean())
print("Total Profit:", df['Profit'].sum())

print("\nRegion-wise Orders:")
print(df['Region'].value_counts())

print("\nCategory-wise Orders:")
print(df['Category'].value_counts())

plt.hist(df['Sales'])
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.title('Sales Distribution')
plt.show()

df['Category'].value_counts().plot(kind='bar')
plt.xlabel('Category')
plt.ylabel('Count')
plt.title('Category-wise Sales Count')
plt.show()

plt.boxplot(df['Profit'])
plt.title('Profit Box Plot')
plt.show()
# Out:
#      <input type="file" id="files-cdf9331d-dabf-499e-9472-f5a83af09610" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cdf9331d-dabf-499e-9472-f5a83af09610">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files

# Upload dataset
files.upload()

# Load dataset
df = pd.read_csv('large_sales_data (1).csv')

# 1. Correlation analysis (WHY profit changes)
print("Correlation Matrix:")
print(df[['Sales','Profit','Quantity']].corr())

# 2. Category-wise profit (reason for high/low profit)
print("\nCategory-wise Average Profit:")
print(df.groupby('Category')['Profit'].mean())

# 3. Region-wise sales comparison
print("\nRegion-wise Total Sales:")
print(df.groupby('Region')['Sales'].sum())

# 4. Sales vs Profit relationship
plt.scatter(df['Sales'], df['Profit'])
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.title('Sales vs Profit')
plt.show()

# 5. Category-wise profit visualization
df.groupby('Category')['Profit'].mean().plot(kind='bar')
plt.title('Average Profit by Category')
plt.show()
# Out:
#      <input type="file" id="files-05524c0d-dce6-4079-abbe-e1abfbb3e25d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-05524c0d-dce6-4079-abbe-e1abfbb3e25d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
from google.colab import files
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Upload dataset
files.upload()

# Load dataset
df = pd.read_csv('large_sales_data (1).csv')

# Input (X) and Output (y)
X = df[['Sales']]
y = df['Profit']

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Train model
model = LinearRegression()
model.fit(X_train, y_train)

# Prediction
y_pred = model.predict(X_test)

# Model evaluation
print("Mean Squared Error:", mean_squared_error(y_test, y_pred))

# Predict profit for new sales value
print("Predicted Profit for Sales = 5000:", model.predict([[5000]])[0])
# Out:
#      <input type="file" id="files-924049d7-c464-4085-92a1-40175fcb4661" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-924049d7-c464-4085-92a1-40175fcb4661">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
